# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame()
df['x'] = np.random.uniform(0,10,100)
df['y'] = np.random.uniform(0,10,100)
df['cat1'] = np.random.uniform(0,3,100)
df['cat2'] = np.random.uniform(0,3,100)

df.plot.scatter(x='x', y='y', by='cat1')
plt.show()
